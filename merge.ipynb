# %%
import pandas as pd
import pandas as pd
import glob
import os

def map_id(x):
    return str(x).lower().replace('.', '').replace(' ', '').replace(':', '').replace('-', '').replace('\xa0', '').replace(',', '').replace('+', '').replace('<sup>', '').replace('</sup>', '')


def get_df(s, path = 'data/', onlylast=False):
    li = []
    files = glob.glob(os.path.join(path , s + "*.csv"))
    for filename in files if not onlylast else [files[-1]]:
        print(filename)
        df = pd.read_csv(filename, index_col=None, header=0, encoding='utf-8')
        li.append(df)

    
    all_df = pd.concat(li, axis=0, ignore_index=True)
    all_df = all_df.drop_duplicates()
    all_df["citeid"] = all_df["Paper title"].apply(lambda x: map_id(x))
    all_df["citingid"] = all_df["Citing paper title"].apply(lambda x: map_id(x))
    return all_df

# %%
scholar = get_df('scholar')  # get the scholar citations
scholar
# Out:
# data\scholar-citations-1676383226.4907641.csv
# data\scholar-citations-1676390245.6953535.csv
# data\scholar-citations-1676633623.8536773.csv
# data\scholar-citations-1676902413.7930026.csv
# data\scholar-citations-1677504445.7159173.csv
# data\scholar-citations-1678117540.5000184.csv
# data\scholar-citations-1678179464.9919195.csv
# data\scholar-citations-1680517501.2175415.csv
# data\scholar-citations-1681200623.1668324.csv
# data\scholar-citations-1683799837.6045644.csv
# data\scholar-citations-1684155368.4507754.csv
# data\scholar-citations-1684156883.008631.csv
# data\scholar-citations.csv
#                                             Paper title  \
# 0     Crop management with the iot: An interdiscipli...
# 1     Crop management with the iot: An interdiscipli...
# 2     Crop management with the iot: An interdiscipli...
# 3     Crop management with the iot: An interdiscipli...
# 4     Crop management with the iot: An interdiscipli...
# ...                                                 ...
# 1851  A-BI+: a framework for Augmented Business Inte...
# 1866  Social BI to understand the debate on vaccines...
# 1886           Making data platforms smarter with MOSES
# 1912       Supporting the Generation of Data Narratives
# 1913       Supporting the Generation of Data Narratives
#
#                                      Citing paper title  \
# 0     AgriFusion: An architecture for IoT and emergi...
# 1     Everything you wanted to know about smart agri...
# 2     Prediction of pest insect appearance using sen...
# 3     A smart and mechanized agricultural applicatio...
# 4     Machine Learning in Precision Agriculture: A S...
# ...                                                 ...
# 1851  Soluci�n de inteligencia de negocios para el a...
# 1866  Understanding public perceptions of COVID-19 c...
# 1886  Ecossistemas de big data: uma revis�o sistem�tica
# 1912          Mod�liser la d�marche du data journaliste
# 1913       Un mod�le conceptual de narration de donn�es
#
#                                                  citeid  \
# 0     cropmanagementwiththeiotaninterdisciplinarysurvey
# 1     cropmanagementwiththeiotaninterdisciplinarysurvey
# 2     cropmanagementwiththeiotaninterdisciplinarysurvey
# 3     cropmanagementwiththeiotaninterdisciplinarysurvey
# 4     cropmanagementwiththeiotaninterdisciplinarysurvey
# ...                                                 ...
# 1851      abiaframeworkforaugmentedbusinessintelligence
# 1866  socialbitounderstandthedebateonvaccinesonthewe...
# 1886                makingdataplatformssmarterwithmoses
# 1912            supportingthegenerationofdatanarratives
# 1913            supportingthegenerationofdatanarratives
#
#                                                citingid
# 0     agrifusionanarchitectureforiotandemergingtechn...
# 1        everythingyouwantedtoknowaboutsmartagriculture
# 2     predictionofpestinsectappearanceusingsensorsan...
# 3     asmartandmechanizedagriculturalapplicationfrom...
# 4     machinelearninginprecisionagricultureasurveyon...
# ...                                                 ...
# 1851  soluci�ndeinteligenciadenegociosparaelaprovech...
# 1866  understandingpublicperceptionsofcovid19contact...
# 1886         ecossistemasdebigdataumarevis�osistem�tica
# 1912               mod�liserlad�marchedudatajournaliste
# 1913             unmod�leconceptualdenarrationdedonn�es
#
# [223 rows x 4 columns]

# %%
scopus = get_df('scopus', onlylast=True)  # get the scopus citations
# scopus = scopus[scopus["citingid"].apply(lambda x: x == x and x != "nan")]
scopus
# Out:
# data\scopus-citations-1684156793.4910352.csv
#                                            Paper title           Paper eid  \
# 0    HAMLET: A framework for Human-centered AutoML ...  2-s2.0-85145965157
# 1       Trajectory-Based Spatiotemporal Entity Linking  2-s2.0-85096846619
# 2       Trajectory-Based Spatiotemporal Entity Linking  2-s2.0-85096846619
# 3       Trajectory-Based Spatiotemporal Entity Linking  2-s2.0-85096846619
# 4       Trajectory-Based Spatiotemporal Entity Linking  2-s2.0-85096846619
# ..                                                 ...                 ...
# 164                        A methodology for social BI  2-s2.0-84906819575
# 165                        A methodology for social BI  2-s2.0-84906819575
# 166                        A methodology for social BI  2-s2.0-84906819575
# 167                        A methodology for social BI  2-s2.0-84906819575
# 168                        A methodology for social BI  2-s2.0-84906819575
#
#                         Paper doi  \
# 0    10.1016/j.future.2022.12.035
# 1       10.1109/TKDE.2020.3036633
# 2       10.1109/TKDE.2020.3036633
# 3       10.1109/TKDE.2020.3036633
# 4       10.1109/TKDE.2020.3036633
# ..                            ...
# 164       10.1145/2628194.2628250
# 165       10.1145/2628194.2628250
# 166       10.1145/2628194.2628250
# 167       10.1145/2628194.2628250
# 168       10.1145/2628194.2628250
#
#                                     Citing paper title    Citing paper eid  \
# 0                                                  NaN                 NaN
# 1    A Survey and Experimental Study on Privacy-Pre...  2-s2.0-85132525373
# 2    Leveraging user itinerary to improve personali...  2-s2.0-85149039992
# 3    Spatial Data Quality in the IoT Era: Managemen...  2-s2.0-85132711904
# 4    Spatial Data Quality in the Internet of Things...  2-s2.0-85137576224
# ..                                                 ...                 ...
# 164  Design issues in social business intelligence ...  2-s2.0-84978698679
# 165             Social business intelligence in action  2-s2.0-84976641685
# 166  Advanced topic modeling for social business in...  2-s2.0-84933670348
# 167  A dynamic approach to information quality in u...  2-s2.0-85126630637
# 168  Automatically tailoring semantics-enabled dime...  2-s2.0-84943606006
#
#                  Citing paper doi  \
# 0                             NaN
# 1       10.1109/TKDE.2022.3174204
# 2      10.1007/s00778-023-00787-z
# 3         10.1145/3514221.3522568
# 4                 10.1145/3498338
# ..                            ...
# 164   10.1007/978-3-319-39243-1_3
# 165    10.1007/978-3-319-39696-53
# 166      10.1016/j.is.2015.04.005
# 167                           NaN
# 168  10.1007/978-3-319-22729-0_16
#
#                                                 citeid  \
# 0    hamletaframeworkforhumancenteredautomlviastruc...
# 1           trajectorybasedspatiotemporalentitylinking
# 2           trajectorybasedspatiotemporalentitylinking
# 3           trajectorybasedspatiotemporalentitylinking
# 4           trajectorybasedspatiotemporalentitylinking
# ..                                                 ...
# 164                            amethodologyforsocialbi
# 165                            amethodologyforsocialbi
# 166                            amethodologyforsocialbi
# 167                            amethodologyforsocialbi
# 168                            amethodologyforsocialbi
#
#                                               citingid
# 0                                                  nan
# 1    asurveyandexperimentalstudyonprivacypreserving...
# 2    leveraginguseritinerarytoimprovepersonalizedde...
# 3    spatialdataqualityintheioteramanagementandexpl...
# 4    spatialdataqualityintheinternetofthingsmanagem...
# ..                                                 ...
# 164   designissuesinsocialbusinessintelligenceprojects
# 165                 socialbusinessintelligenceinaction
# 166  advancedtopicmodelingforsocialbusinessintellig...
# 167  adynamicapproachtoinformationqualityinusergene...
# 168  automaticallytailoringsemanticsenableddimensio...
#
# [169 rows x 8 columns]

# %%
scopus.groupby(by=["citeid"])["citingid"].count().sort_values(ascending=False)
# Out:
# citeid
# cropmanagementwiththeiotaninterdisciplinarysurvey                                                                18
# amethodologyforsocialbi                                                                                          16
# towardsafoundationalapiforresilientdistributedsystemsdesign                                                      14
# towardsconversationalolap                                                                                        11
# abiaframeworkforaugmentedbusinessintelligence                                                                     9
# towardsaconceptualmodelfordatanarratives                                                                          9
# socialbusinessintelligenceinaction                                                                                8
# asurveyandexperimentalstudyonprivacypreservingtrajectorydatapublishing                                            7
# enhancingcubeswithmodelstodescribemultidimensionaldata                                                            6
# socialbitounderstandthedebateonvaccinesonthewebandsocialmediaunravelingtheantifreeandprovaxcommunitiesinitaly     6
# makingdataplatformssmarterwithmoses                                                                               6
# trajectorybasedspatiotemporalentitylinking                                                                        6
# coolaframeworkforconversationalolap                                                                               6
# augmentedbusinessintelligence                                                                                     6
# summarizationandvisualizationofmultilevelandmultidimensionalitemsets                                              5
# assessqueriesforinteractiveanalysisofdatacubes                                                                    5
# supportingthegenerationofdatanarratives                                                                           5
# mapmatchingonbigdataadistributedandefficientalgorithmwithahiddenmarkovmodel                                       4
# dartdeanonymizationofpersonalgazetteersthroughsocialtrajectories                                                  4
# thetelltalecube                                                                                                   4
# optimizingexecutionplansinamultistore                                                                             3
# multisensorprofilingforprecisionsoilmoisturemonitoring                                                            2
# describingmultidimensionaldatathroughhighlights(discussionpaper)                                                  1
# asimilarityfunctionformultilevelandmultidimensionalitemsets                                                       1
# conversationalolapinaction                                                                                        1
# suggestingassessqueriesforinteractiveanalysisofmultidimensionaldata                                               1
# conversationalolap                                                                                                1
# olapqueryingofdocumentstoresinthepresenceofschemavariety                                                          1
# costbasedoptimizationofmultistorequeryplans                                                                       1
# hamletaframeworkforhumancenteredautomlviastructuredargumentation                                                  1
# insightbasedvocalizationofolapsessions                                                                            1
# Name: citingid, dtype: int64

# %%
scopus_papers = scopus[["Paper title", "Paper eid", "Paper doi", "citeid"]].drop_duplicates().sort_values(by=["Paper title"]).reset_index(drop=True)
scopus_papers
# Out:
#                                           Paper title           Paper eid  \
# 0   A Similarity Function for Multi-Level and Mult...  2-s2.0-85051863772
# 1   A Survey and Experimental Study on Privacy-Pre...  2-s2.0-85132525373
# 2                         A methodology for social BI  2-s2.0-84906819575
# 3   A-BI<sup>+</sup>: A framework for Augmented Bu...  2-s2.0-85082441558
# 4   Assess queries for interactive analysis of dat...  2-s2.0-85113712544
# 5                     Augmented business intelligence  2-s2.0-85062645475
# 6           COOL: A framework for conversational OLAP  2-s2.0-85103428030
# 7                                 Conversational OLAP  2-s2.0-85118769792
# 8                       Conversational OLAP in action  2-s2.0-85113716450
# 9   Cost-based Optimization of Multistore Query Plans  2-s2.0-85139405955
# 10  Crop Management with the IoT: An Interdiscipli...  2-s2.0-85100942957
# 11  DART: De-Anonymization of personal gazetteers ...  2-s2.0-85093926143
# 12  Describing Multidimensional Data Through Highl...  2-s2.0-85137469232
# 13  Enhancing Cubes with Models to Describe Multid...  2-s2.0-85107683405
# 14  HAMLET: A framework for Human-centered AutoML ...  2-s2.0-85145965157
# 15        Insight-Based Vocalization of OLAP Sessions  2-s2.0-85137993971
# 16           Making data platforms smarter with MOSES  2-s2.0-85109035166
# 17  Map-matching on big data: A distributed and ef...  2-s2.0-85070329171
# 18  Multi-sensor profiling for precision soil-mois...  2-s2.0-85129541562
# 19  OLAP Querying of Document Stores in the Presen...  2-s2.0-85090883258
# 20         Optimizing Execution Plans in a Multistore  2-s2.0-85115134032
# 21  Social BI to understand the debate on vaccines...  2-s2.0-85070525370
# 22             Social business intelligence in action  2-s2.0-84976641685
# 23  Suggesting assess queries for interactive anal...  2-s2.0-85129353199
# 24  Summarization and visualization of multi-level...  2-s2.0-85079239065
# 25       Supporting the generation of data narratives  2-s2.0-85095734112
# 26                                 The Tell-Tale Cube  2-s2.0-85090100247
# 27     Towards a Conceptual Model for Data Narratives  2-s2.0-85097380415
# 28  Towards a foundational API for resilient distr...  2-s2.0-85035209468
# 29                        Towards conversational OLAP  2-s2.0-85082444588
# 30     Trajectory-Based Spatiotemporal Entity Linking  2-s2.0-85096846619
#
#                        Paper doi  \
# 0                            NaN
# 1      10.1109/TKDE.2022.3174204
# 2        10.1145/2628194.2628250
# 3       10.1016/j.is.2020.101520
# 4       10.5441/002/edbt.2021.12
# 5                            NaN
# 6       10.1016/j.is.2021.101752
# 7                            NaN
# 8       10.5441/002/edbt.2021.74
# 9     10.1007/s10796-022-10320-2
# 10      10.3390/agronomy11010181
# 11    10.1016/j.jisa.2020.102634
# 12                           NaN
# 13    10.1007/s10796-021-10147-3
# 14  10.1016/j.future.2022.12.035
# 15  10.1007/978-3-031-15740-0_15
# 16  10.1016/j.future.2021.06.031
# 17   10.23919/MIPRO.2019.8757119
# 18  10.1016/j.compag.2022.106924
# 19                           NaN
# 20  10.1007/978-3-030-82472-3_11
# 21     10.1007/s13278-019-0590-x
# 22    10.1007/978-3-319-39696-53
# 23     10.1109/TKDE.2022.3171516
# 24     10.1016/j.ins.2020.02.006
# 25                           NaN
# 26  10.1007/978-3-030-54832-2_16
# 27  10.1007/978-3-030-62522-1_19
# 28        10.1109/FAS-W.2017.116
# 29                           NaN
# 30     10.1109/TKDE.2020.3036633
#
#                                                citeid
# 0   asimilarityfunctionformultilevelandmultidimens...
# 1   asurveyandexperimentalstudyonprivacypreserving...
# 2                             amethodologyforsocialbi
# 3       abiaframeworkforaugmentedbusinessintelligence
# 4      assessqueriesforinteractiveanalysisofdatacubes
# 5                       augmentedbusinessintelligence
# 6                 coolaframeworkforconversationalolap
# 7                                  conversationalolap
# 8                          conversationalolapinaction
# 9         costbasedoptimizationofmultistorequeryplans
# 10  cropmanagementwiththeiotaninterdisciplinarysurvey
# 11  dartdeanonymizationofpersonalgazetteersthrough...
# 12  describingmultidimensionaldatathroughhighlight...
# 13  enhancingcubeswithmodelstodescribemultidimensi...
# 14  hamletaframeworkforhumancenteredautomlviastruc...
# 15             insightbasedvocalizationofolapsessions
# 16                makingdataplatformssmarterwithmoses
# 17  mapmatchingonbigdataadistributedandefficiental...
# 18  multisensorprofilingforprecisionsoilmoisturemo...
# 19  olapqueryingofdocumentstoresinthepresenceofsch...
# 20              optimizingexecutionplansinamultistore
# 21  socialbitounderstandthedebateonvaccinesonthewe...
# 22                 socialbusinessintelligenceinaction
# 23  suggestingassessqueriesforinteractiveanalysiso...
# 24  summarizationandvisualizationofmultilevelandmu...
# 25            supportingthegenerationofdatanarratives
# 26                                    thetelltalecube
# 27           towardsaconceptualmodelfordatanarratives
# 28  towardsafoundationalapiforresilientdistributed...
# 29                          towardsconversationalolap
# 30         trajectorybasedspatiotemporalentitylinking

# %%
scopus_papers.groupby(by=["citeid"]).count()
# Out:
#                                                     Paper title  Paper eid  \
# citeid
# abiaframeworkforaugmentedbusinessintelligence                 1          1
# amethodologyforsocialbi                                       1          1
# asimilarityfunctionformultilevelandmultidimensi...            1          1
# assessqueriesforinteractiveanalysisofdatacubes                1          1
# asurveyandexperimentalstudyonprivacypreservingt...            1          1
# augmentedbusinessintelligence                                 1          1
# conversationalolap                                            1          1
# conversationalolapinaction                                    1          1
# coolaframeworkforconversationalolap                           1          1
# costbasedoptimizationofmultistorequeryplans                   1          1
# cropmanagementwiththeiotaninterdisciplinarysurvey             1          1
# dartdeanonymizationofpersonalgazetteersthroughs...            1          1
# describingmultidimensionaldatathroughhighlights...            1          1
# enhancingcubeswithmodelstodescribemultidimensio...            1          1
# hamletaframeworkforhumancenteredautomlviastruct...            1          1
# insightbasedvocalizationofolapsessions                        1          1
# makingdataplatformssmarterwithmoses                           1          1
# mapmatchingonbigdataadistributedandefficientalg...            1          1
# multisensorprofilingforprecisionsoilmoisturemon...            1          1
# olapqueryingofdocumentstoresinthepresenceofsche...            1          1
# optimizingexecutionplansinamultistore                         1          1
# socialbitounderstandthedebateonvaccinesontheweb...            1          1
# socialbusinessintelligenceinaction                            1          1
# suggestingassessqueriesforinteractiveanalysisof...            1          1
# summarizationandvisualizationofmultilevelandmul...            1          1
# supportingthegenerationofdatanarratives                       1          1
# thetelltalecube                                               1          1
# towardsaconceptualmodelfordatanarratives                      1          1
# towardsafoundationalapiforresilientdistributeds...            1          1
# towardsconversationalolap                                     1          1
# trajectorybasedspatiotemporalentitylinking                    1          1
#
#                                                     Paper doi
# citeid
# abiaframeworkforaugmentedbusinessintelligence               1
# amethodologyforsocialbi                                     1
# asimilarityfunctionformultilevelandmultidimensi...          0
# assessqueriesforinteractiveanalysisofdatacubes              1
# asurveyandexperimentalstudyonprivacypreservingt...          1
# augmentedbusinessintelligence                               0
# conversationalolap                                          0
# conversationalolapinaction                                  1
# coolaframeworkforconversationalolap                         1
# costbasedoptimizationofmultistorequeryplans                 1
# cropmanagementwiththeiotaninterdisciplinarysurvey           1
# dartdeanonymizationofpersonalgazetteersthroughs...          1
# describingmultidimensionaldatathroughhighlights...          0
# enhancingcubeswithmodelstodescribemultidimensio...          1
# hamletaframeworkforhumancenteredautomlviastruct...          1
# insightbasedvocalizationofolapsessions                      1
# makingdataplatformssmarterwithmoses                         1
# mapmatchingonbigdataadistributedandefficientalg...          1
# multisensorprofilingforprecisionsoilmoisturemon...          1
# olapqueryingofdocumentstoresinthepresenceofsche...          0
# optimizingexecutionplansinamultistore                       1
# socialbitounderstandthedebateonvaccinesontheweb...          1
# socialbusinessintelligenceinaction                          1
# suggestingassessqueriesforinteractiveanalysisof...          1
# summarizationandvisualizationofmultilevelandmul...          1
# supportingthegenerationofdatanarratives                     0
# thetelltalecube                                             1
# towardsaconceptualmodelfordatanarratives                    1
# towardsafoundationalapiforresilientdistributeds...          1
# towardsconversationalolap                                   0
# trajectorybasedspatiotemporalentitylinking                  1

# %%
scopus_lookup = {}
for x in scopus_papers.to_numpy():
    scopus_lookup[x[3]] = x[:3]

# %%
scopus_unique = scopus["citeid"].sort_values().unique()
scopus_unique
# Out:
# array(['abiaframeworkforaugmentedbusinessintelligence',
#        'amethodologyforsocialbi',
#        'asimilarityfunctionformultilevelandmultidimensionalitemsets',
#        'assessqueriesforinteractiveanalysisofdatacubes',
#        'asurveyandexperimentalstudyonprivacypreservingtrajectorydatapublishing',
#        'augmentedbusinessintelligence', 'conversationalolap',
#        'conversationalolapinaction',
#        'coolaframeworkforconversationalolap',
#        'costbasedoptimizationofmultistorequeryplans',
#        'cropmanagementwiththeiotaninterdisciplinarysurvey',
#        'dartdeanonymizationofpersonalgazetteersthroughsocialtrajectories',
#        'describingmultidimensionaldatathroughhighlights(discussionpaper)',
#        'enhancingcubeswithmodelstodescribemultidimensionaldata',
#        'hamletaframeworkforhumancenteredautomlviastructuredargumentation',
#        'insightbasedvocalizationofolapsessions',
#        'makingdataplatformssmarterwithmoses',
#        'mapmatchingonbigdataadistributedandefficientalgorithmwithahiddenmarkovmodel',
#        'multisensorprofilingforprecisionsoilmoisturemonitoring',
#        'olapqueryingofdocumentstoresinthepresenceofschemavariety',
#        'optimizingexecutionplansinamultistore',
#        'socialbitounderstandthedebateonvaccinesonthewebandsocialmediaunravelingtheantifreeandprovaxcommunitiesinitaly',
#        'socialbusinessintelligenceinaction',
#        'suggestingassessqueriesforinteractiveanalysisofmultidimensionaldata',
#        'summarizationandvisualizationofmultilevelandmultidimensionalitemsets',
#        'supportingthegenerationofdatanarratives', 'thetelltalecube',
#        'towardsaconceptualmodelfordatanarratives',
#        'towardsafoundationalapiforresilientdistributedsystemsdesign',
#        'towardsconversationalolap',
#        'trajectorybasedspatiotemporalentitylinking'], dtype=object)

# %%
scholar_unique = scholar["citeid"].sort_values().unique()
scholar_unique
# Out:
# array(['abiaframeworkforaugmentedbusinessintelligence',
#        'asimilarityfunctionformultilevelandmultidimensionalitemsets',
#        'assessqueriesforinteractiveanalysisofdatacubes',
#        'asurveyandexperimentalstudyonprivacypreservingtrajectorydatapublishing',
#        'augmentedbusinessintelligence', 'conversationalolapinaction',
#        'coolaframeworkforconversationalolap',
#        'costbasedoptimizationofmultistorequeryplans',
#        'cropmanagementwiththeiotaninterdisciplinarysurvey',
#        'dartdeanonymizationofpersonalgazetteersthroughsocialtrajectories',
#        'enhancingcubeswithmodelstodescribemultidimensionaldata',
#        'makingdataplatformssmarterwithmoses',
#        'mapmatchingonbigdataadistributedandefficientalgorithmwithahiddenmarkovmodel',
#        'multisensorprofilingforprecisionsoilmoisturemonitoring',
#        'olapqueryingofdocumentstoresinthepresenceofschemavariety',
#        'optimizingexecutionplansinamultistore',
#        'socialbitounderstandthedebateonvaccinesonthewebandsocialmediaunravelingtheantifreeandprovaxcommunitiesinitaly',
#        'suggestingassessqueriesforinteractiveanalysisofmultidimensionaldata',
#        'summarizationandvisualizationofmultilevelandmultidimensionalitemsets',
#        'supportingthegenerationofdatanarratives', 'thetelltalecube',
#        'towardsaconceptualmodelfordatanarratives',
#        'towardsafoundationalapiforresilientdistributedsystemsdesign',
#        'towardsconversationalolap',
#        'trajectorybasedspatiotemporalentitylinking'], dtype=object)

# %%
not_cited_ids = []
for x in scholar_unique:  # for each paper in scholar
    citations_scholar = scholar[scholar["citeid"] == x]  # get its citing papers from scholar
    paper_scopus = scopus[(scopus["citeid"] == x)]  # get the paper from scopus...
    if len(paper_scopus) == 0:  # if the paper is not on scopus...
        print(x + " is not in scopus")
    else:
        for y in citations_scholar["citingid"].unique():  # for each of the citing papers from scholar
            if len(paper_scopus[(scopus["citingid"] == y)]) == 0:  # if this citation is not in scopus...
                not_cited_ids.append([x, y])  # add it
not_cited = pd.DataFrame(not_cited_ids, columns=["citeid", "citingid"])
not_cited
# Out:
# C:\Users\matteo.francia5\AppData\Local\Temp\ipykernel_27596\698780769.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if len(paper_scopus[(scopus["citingid"] == y)]) == 0:  # if this citation is not in scopus...
#                                             citeid  \
# 0    abiaframeworkforaugmentedbusinessintelligence
# 1    abiaframeworkforaugmentedbusinessintelligence
# 2    abiaframeworkforaugmentedbusinessintelligence
# 3    abiaframeworkforaugmentedbusinessintelligence
# 4    abiaframeworkforaugmentedbusinessintelligence
# ..                                             ...
# 97                       towardsconversationalolap
# 98      trajectorybasedspatiotemporalentitylinking
# 99      trajectorybasedspatiotemporalentitylinking
# 100     trajectorybasedspatiotemporalentitylinking
# 101     trajectorybasedspatiotemporalentitylinking
#
#                                               citingid
# 0    lainteligenciadenegociosylaanalíticadedatosenl...
# 1    theimpactofbusinessintelligencecharacteristics...
# 2    augmentingtheknowledgepyramidwithunconventiona...
# 3    lainteligenciadenegociosylaanalíticadedatosenl...
# 4    solucióndeinteligenciadenegociosparaelaprovech...
# ..                                                 ...
# 97   describingandassessingcubesthroughintentionala...
# 98   informationresiliencethenexusofresponsibleanda...
# 99   anefficientapproachforspatialtrajectoryanonymi...
# 100  augmentingtheknowledgepyramidwithunconventiona...
# 101  trajectoryuserlinkingviahierarchicalspatiotemp...
#
# [102 rows x 2 columns]

# %%
missing_papers = scholar[["Citing paper title", "citingid"]].drop_duplicates().merge(not_cited, on=["citingid"])
missing_papers
# Out:
#                                     Citing paper title  \
# 0    Everything you wanted to know about smart agri...
# 1    Analysis of chlorophyll and carotenoids conten...
# 2    LambdAgrIoT: a new architecture for agricultur...
# 3    An Intelligent Agro-Cloud Framework For Effici...
# 4    A model for automatized data integration in ha...
# ..                                                 ...
# 97   The Impact of Business Intelligence Characteri...
# 98   La inteligencia de negocios y la anal�tica de ...
# 99   Soluci�n de inteligencia de negocios para el a...
# 100  Understanding public perceptions of COVID-19 c...
# 101  Ecossistemas de big data: uma revis�o sistem�tica
#
#                                               citingid  \
# 0       everythingyouwantedtoknowaboutsmartagriculture
# 1    analysisofchlorophyllandcarotenoidscontentinbr...
# 2    lambdagriotanewarchitectureforagriculturalauto...
# 3    anintelligentagrocloudframeworkforefficientcro...
# 4    amodelforautomatizeddataintegrationinhadoopbas...
# ..                                                 ...
# 97   theimpactofbusinessintelligencecharacteristics...
# 98   lainteligenciadenegociosylaanal�ticadedatosenl...
# 99   soluci�ndeinteligenciadenegociosparaelaprovech...
# 100  understandingpublicperceptionsofcovid19contact...
# 101         ecossistemasdebigdataumarevis�osistem�tica
#
#                                                 citeid
# 0    cropmanagementwiththeiotaninterdisciplinarysurvey
# 1    cropmanagementwiththeiotaninterdisciplinarysurvey
# 2    cropmanagementwiththeiotaninterdisciplinarysurvey
# 3    cropmanagementwiththeiotaninterdisciplinarysurvey
# 4    cropmanagementwiththeiotaninterdisciplinarysurvey
# ..                                                 ...
# 97       abiaframeworkforaugmentedbusinessintelligence
# 98       abiaframeworkforaugmentedbusinessintelligence
# 99       abiaframeworkforaugmentedbusinessintelligence
# 100  socialbitounderstandthedebateonvaccinesonthewe...
# 101                makingdataplatformssmarterwithmoses
#
# [102 rows x 3 columns]

# %%
scopus_acc = []
not_in_scopus = []
missin_papers_scopus = pd.DataFrame(scopus_acc, columns=["Citing paper title", "Citing paper eid", "Citing paper doi", "citingid"]).drop_duplicates()

# %%
import pybliometrics
from pybliometrics.scopus import ScopusSearch
from pybliometrics.scopus.utils import config
from pybliometrics.scopus import AuthorRetrieval
import sys
import pandas as pd
import time

for x in missing_papers[["Citing paper title", "citingid"]].drop_duplicates().to_numpy():  # [["making data platform smarter with moses"]]:
    string = "TITLE-ABS-KEY({})".format(' AND '.join(x[0].lower().split(' ')))
    try:
        s = ScopusSearch(string)
        if s.results is not None and len(s.results) > 0:
            papers = [[y.title, y.eid, y.doi, x[1]] for y in s.results]
            for paper in papers:
                scopus_acc = scopus_acc + [paper]
                missin_papers_scopus = pd.DataFrame(scopus_acc, columns=["Citing paper title", "Citing paper eid", "Citing paper doi", "citingid"]).drop_duplicates()
        else:
            not_in_scopus = not_in_scopus + [x[0]]
        time.sleep(1)
    except Exception as e:
        print(x[0] + " " + string + ": " + str(e))
# Out:
# Analysis of chlorophyll and carotenoids content in brassica chinensis plants using IoT-based sprinkle irrigation TITLE-ABS-KEY(analysis AND of AND chlorophyll AND and AND carotenoids AND content AND in AND brassica AND chinensis AND plants AND using AND iot-based AND sprinkle AND irrigation): Error translating query
# Augmenting the Knowledge Pyramid with Unconventional Data and Advanced Analytics TITLE-ABS-KEY(augmenting AND the AND knowledge AND pyramid AND with AND unconventional AND data AND and AND advanced AND analytics): Error translating query
# Distributed Applications and Interoperable Systems TITLE-ABS-KEY(distributed AND applications AND and AND interoperable AND systems): Error translating query
# Distributed and Decentralized Algorithms for Functional Programmable Matter TITLE-ABS-KEY(distributed AND and AND decentralized AND algorithms AND for AND functional AND programmable AND matter): Error translating query
# Narrative Visualizations Best Practices and Evaluation: A Systematic Mapping Study TITLE-ABS-KEY(narrative AND visualizations AND best AND practices AND and AND evaluation: AND a AND systematic AND mapping AND study): Error translating query
# The Impact of Business Intelligence Characteristics on Competitiveness of Companies with the Mediating Role of Entrepreneurship, Market Orientation and Business … TITLE-ABS-KEY(the AND impact AND of AND business AND intelligence AND characteristics AND on AND competitiveness AND of AND companies AND with AND the AND mediating AND role AND of AND entrepreneurship, AND market AND orientation AND and AND business AND …): Error translating query
# La inteligencia de negocios y la analítica de datos en los procesos empresariales Business intelligence and data analytics in business processes TITLE-ABS-KEY(la AND inteligencia AND de AND negocios AND y AND la AND analítica AND de AND datos AND en AND los AND procesos AND empresariales AND business AND intelligence AND and AND data AND analytics AND in AND business AND processes): Error translating query
# Conceptualizing Analytics: An Overview of Business Intelligence and Analytics from a Conceptual-Modeling Perspective TITLE-ABS-KEY(conceptualizing AND analytics: AND an AND overview AND of AND business AND intelligence AND and AND analytics AND from AND a AND conceptual-modeling AND perspective): Error translating query
# Concepts towards an automated data pre-processing and preparation within data lakes TITLE-ABS-KEY(concepts AND towards AND an AND automated AND data AND pre-processing AND and AND preparation AND within AND data AND lakes): Error translating query
# Information Resilience: the nexus of responsible and agile approaches to information use TITLE-ABS-KEY(information AND resilience: AND the AND nexus AND of AND responsible AND and AND agile AND approaches AND to AND information AND use): Error translating query
# SeRViz: an interactive visualization framework for the analysis of sequential rules and frequent itemsets TITLE-ABS-KEY(serviz: AND an AND interactive AND visualization AND framework AND for AND the AND analysis AND of AND sequential AND rules AND and AND frequent AND itemsets): Error translating query
# Serviz: A Visual Analytics System for the Analysis of Sequential Rules and its Application to Airport Ground Handling Operations TITLE-ABS-KEY(serviz: AND a AND visual AND analytics AND system AND for AND the AND analysis AND of AND sequential AND rules AND and AND its AND application AND to AND airport AND ground AND handling AND operations): Error translating query
# Towards Privacy Preservation using Clustering based Anonymization: Recent Advances and Future Research Outlook TITLE-ABS-KEY(towards AND privacy AND preservation AND using AND clustering AND based AND anonymization: AND recent AND advances AND and AND future AND research AND outlook): Error translating query
# A Scalable Device for Undisturbed Measurement of Water and CO2 Fluxes through Natural Surfaces TITLE-ABS-KEY(a AND scalable AND device AND for AND undisturbed AND measurement AND of AND water AND and AND co2 AND fluxes AND through AND natural AND surfaces): Error translating query
# Data Narration for the People: Challenges and Opportunities TITLE-ABS-KEY(data AND narration AND for AND the AND people: AND challenges AND and AND opportunities): Error translating query
# Describing and Assessing Cubes Through Intentional Analytics TITLE-ABS-KEY(describing AND and AND assessing AND cubes AND through AND intentional AND analytics): Error translating query
# Design and Implementation of a Framework for Smart Home Automation Based on Cellular IoT, MQTT, and Serverless Functions TITLE-ABS-KEY(design AND and AND implementation AND of AND a AND framework AND for AND smart AND home AND automation AND based AND on AND cellular AND iot, AND mqtt, AND and AND serverless AND functions): Error translating query
# Sustainable Energy Storage Devices and Device Design for Sensors and Actuators Applications TITLE-ABS-KEY(sustainable AND energy AND storage AND devices AND and AND device AND design AND for AND sensors AND and AND actuators AND applications): Error translating query
# Mining Data Wrangling Workflows for Patterns, Reuse and Optimisation Opportunities TITLE-ABS-KEY(mining AND data AND wrangling AND workflows AND for AND patterns, AND reuse AND and AND optimisation AND opportunities): Error translating query
# Fouille de s�quences de mobilit� s�mantique: sur l'�laboration de mesures pour la comparaison, l'analyse et la d�couverte de comportements TITLE-ABS-KEY(fouille AND de AND s�quences AND de AND mobilit� AND s�mantique: AND sur AND l'�laboration AND de AND mesures AND pour AND la AND comparaison, AND l'analyse AND et AND la AND d�couverte AND de AND comportements): Error translating query
# Mod�liser la d�marche du data journaliste TITLE-ABS-KEY(mod�liser AND la AND d�marche AND du AND data AND journaliste): Error translating query
# Un mod�le conceptual de narration de donn�es TITLE-ABS-KEY(un AND mod�le AND conceptual AND de AND narration AND de AND donn�es): Error translating query
# La inteligencia de negocios y la anal�tica de datos en los procesos empresariales TITLE-ABS-KEY(la AND inteligencia AND de AND negocios AND y AND la AND anal�tica AND de AND datos AND en AND los AND procesos AND empresariales): Error translating query
# The Impact of Business Intelligence Characteristics on Competitiveness of Companies with the Mediating Role of Entrepreneurship, Market Orientation and Business � TITLE-ABS-KEY(the AND impact AND of AND business AND intelligence AND characteristics AND on AND competitiveness AND of AND companies AND with AND the AND mediating AND role AND of AND entrepreneurship, AND market AND orientation AND and AND business AND �): Error translating query
# La inteligencia de negocios y la anal�tica de datos en los procesos empresariales Business intelligence and data analytics in business processes TITLE-ABS-KEY(la AND inteligencia AND de AND negocios AND y AND la AND anal�tica AND de AND datos AND en AND los AND procesos AND empresariales AND business AND intelligence AND and AND data AND analytics AND in AND business AND processes): Error translating query
# Soluci�n de inteligencia de negocios para el aprovechamiento de los datos del servicio m�dico en una entidad bancaria TITLE-ABS-KEY(soluci�n AND de AND inteligencia AND de AND negocios AND para AND el AND aprovechamiento AND de AND los AND datos AND del AND servicio AND m�dico AND en AND una AND entidad AND bancaria): Error translating query
# Understanding public perceptions of COVID-19 contact tracing apps: Artificial intelligence�enabled social media analysis TITLE-ABS-KEY(understanding AND public AND perceptions AND of AND covid-19 AND contact AND tracing AND apps: AND artificial AND intelligence�enabled AND social AND media AND analysis): Error translating query
# Ecossistemas de big data: uma revis�o sistem�tica TITLE-ABS-KEY(ecossistemas AND de AND big AND data: AND uma AND revis�o AND sistem�tica): Error translating query

# %%
missin_papers_scopus
# Out:
#                                      Citing paper title    Citing paper eid  \
# 0     LambdAgrIoT: a new architecture for agricultur...  2-s2.0-85140242438
# 1     Applications of IoT for optimized greenhouse e...  2-s2.0-85129326292
# 2     Learning Space-Time Crop Yield Patterns with Z...  2-s2.0-85143575925
# 3       IOT based solar powered smart irrigation system  2-s2.0-85131869537
# 4     Utilization of Internet of Things and Wireless...  2-s2.0-85128770051
# ...                                                 ...                 ...
# 9026  Characterization of tillage effects on the spa...  2-s2.0-84879704182
# 9027  Noninvasive monitoring of soil static characte...  2-s2.0-84869385119
# 9028  Mapping soil moisture content variability usin...  2-s2.0-79956139565
# 9029  Diagnosis, extent, impacts, and management of ...  2-s2.0-77950601715
# 9030  Agricultural geophysics: Past, present, and fu...  2-s2.0-84867280434
#
#                     Citing paper doi  \
# 0         10.1007/s10586-022-03592-5
# 1       10.1016/j.compag.2022.106993
# 2                               None
# 3                  10.1063/5.0081783
# 4                  10.3390/s22093273
# ...                              ...
# 9026  10.1016/j.geoderma.2013.05.024
# 9027            10.2136/vzj2011.0195
# 9028                            None
# 9029                 10.1071/SR09074
# 9030               10.4133/1.3445432
#
#                                                citingid
# 0     lambdagriotanewarchitectureforagriculturalauto...
# 1        thingsforsmartagricultureindevelopingcountries
# 2        thingsforsmartagricultureindevelopingcountries
# 3        thingsforsmartagricultureindevelopingcountries
# 4        thingsforsmartagricultureindevelopingcountries
# ...                                                 ...
# 9026  soilmoisturemappingusingelectromagneticinducti...
# 9027  soilmoisturemappingusingelectromagneticinducti...
# 9028  soilmoisturemappingusingelectromagneticinducti...
# 9029  soilmoisturemappingusingelectromagneticinducti...
# 9030  soilmoisturemappingusingelectromagneticinducti...
#
# [9031 rows x 4 columns]

# %%
def filter_col(df):
    df = df[[x for x in df.columns if x != "citingid" and x != "citeid" and "doi" not in x]]
    df = df.rename({"Paper title": "Cited paper title", "Paper eid": "Cited paper eid"}, axis=1)
    df["Cited paper link"] = df["Cited paper eid"].apply(lambda x: "https://www.scopus.com/record/display.uri?eid={}&origin=resultslist".format(x))
    df["Citing paper link"] = df["Citing paper eid"].apply(lambda x: "https://www.scopus.com/record/display.uri?eid={}&origin=resultslist".format(x))
    return df

# %%
filter_col(scopus_papers.merge(not_cited, on=["citeid"]).merge(missin_papers_scopus, on=["citingid"])).sort_values(by=['Cited paper title', 'Citing paper title']).to_csv('data/missing-{}-all.csv'.format(time.time()), index=False)
filter_col(scopus_papers.merge(not_cited, on=["citeid"]).merge(missin_papers_scopus[missin_papers_scopus["citingid"] == missin_papers_scopus["Citing paper title"].apply(lambda x: map_id(x))], on=["citingid"])).sort_values(by=['Cited paper title', 'Citing paper title']).to_csv('data/missing-{}-red.csv'.format(time.time()), index=False)
